# %%
# !pip install torch

# %%
TRAIN = "/kaggle/input/datasets/samasiayushman/small-model-track/Training/Training/data"
TEST =  "/kaggle/input/datasets/samasiayushman/small-model-track/Testing/Testing/small_model_track_test-007/small_model_track_test"

# %%
class_mapping = pd.read_csv(
    os.path.join(TRAIN, "/kaggle/input/datasets/samasiayushman/small-model-track/Training/Training/class_mapping.csv")
)

test = pd.read_csv(
    os.path.join(TEST, "/kaggle/input/datasets/samasiayushman/small-model-track/Testing/Testing/test.csv")
)

sample_submission = pd.read_csv(
    os.path.join(TEST, "/kaggle/input/datasets/samasiayushman/small-model-track/Testing/Testing/sample_submission.csv")
)

print("===== CLASS MAPPING =====")
print(class_mapping)
print(class_mapping.shape)

print("\n===== TEST =====")
print(test.head())
print(test.shape)
print(test.columns)

print("\n===== SAMPLE SUBMISSION =====")
print(sample_submission.head())
print(sample_submission.shape)
print(sample_submission.columns)
# Out:
# ===== CLASS MAPPING =====
#     action_id                         action_name
# 0           0                         0_Wash_face
# 1           1                       1_Brush_teeth
# 2           2                         2_Comb_hair
# 3           3                  3_Take_off_clothes
# 4           4                        4_Wipe_hands
# 5           5                    5_Put_on_clothes
# 6           6                       6_Drink_water
# 7           7                          7_Eat_food
# 8           8            8_Take_and_use_tableware
# 9           9                       9_Pour_drinks
# 10         10                      10_Stir_drinks
# 11         11                      11_Peel_fruits
# 12         12                  12_Sweep_the_floor
# 13         13                    13_Mop_the_floor
# 14         14                       14_Wipe_bowls
# 15         15          15_Wipe_windows_and_tables
# 16         16                     16_Fold_clothes
# ...
